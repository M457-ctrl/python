# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 3.1 Problem - 1:

# %% [markdown]
# # • Dataset Overview:
# # 1. Load the dataset and display the first 10 rows.

# %%
import pandas as pd
Manifile1 = pd.read_csv('/content/drive/MyDrive/Python assigment/WHR-2024-5CS037.csv')
# Printing the top 10 datas
Manifile1.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
Manifile1.describe()
# Out:
#             score  Log GDP per capita  Social support  \
# count  143.000000          140.000000      140.000000
# mean     5.527580            1.378807        1.134329
# std      1.170717            0.425098        0.333317
# min      1.721000            0.000000        0.000000
# 25%      4.726000            1.077750        0.921750
# 50%      5.785000            1.431500        1.237500
# 75%      6.416000            1.741500        1.383250
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               140.000000                    140.000000  140.000000
# mean                  0.520886                      0.620621    0.146271
# std                   0.164923                      0.162492    0.073441
# min                   0.000000                      0.000000    0.000000
# 25%                   0.398000                      0.527500    0.091000
# ...

# %% [markdown]
# # 2. Identify the number of rows and columns in the dataset.

# %%
rows,column=Manifile1.shape
print("Number of rows:", rows)
print("Number of columns:", column)
# Out:
# Number of rows: 143
# Number of columns: 9

# %% [markdown]
# # 3. List all the columns and their data types.

# %%
# dtypes gives the list and type of the all the columns
Manifile1.dtypes
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# # • Basic Statistics:

# %% [markdown]
# # 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
mean = Manifile1['score'].mean()
median = Manifile1['score'].median()
std = Manifile1['score'].std()
print("mean is:",mean)
print("median is:",median)
print("standard deviation is:",std)
# Out:
# mean is: 5.52758041958042
# median is: 5.785
# standard deviation is: 1.1707165099442995

# %% [markdown]
# # 2. Identify the country with the highest and lowest happiness scores.

# %%
#loc is used to give access to specific column
#idmax,idmin is used to find the min and max value of the column
highest = Manifile1.loc[Manifile1['score'].idxmax(), 'Country name']
lowest = Manifile1.loc[Manifile1['score'].idxmin(), 'Country name']
print("Country with highest score:", highest)
print("Country with lowest score:", lowest)
# Out:
# Country with highest score: Finland
# Country with lowest score: Afghanistan

# %% [markdown]
# # • Missing Values:

# %% [markdown]
# # 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
#isnull check if the cell is empty
#sum() adds if the cell is foudn to be null
missing_values = Manifile1.isnull().sum()
print(missing_values)
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# # • Filtering and Sorting:

# %% [markdown]
# # 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
filtered_data = Manifile1[Manifile1['score'] > 7.5]
# Display the filtered dataset
filtered_data['Country name']
# Out:
# 0    Finland
# 1    Denmark
# 2    Iceland
# Name: Country name, dtype: object

# %% [markdown]
# # 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the top 10 rows.

# %%
#by is used to selected the column
#assending=false is used to print in decending order
sorted_data = filtered_data.sort_values(by='Log GDP per capita', ascending=False)
#head is used to print the top 10 rows but we only have 3 rows
print(sorted_data.head(10)[['Country name','Log GDP per capita']])
# Out:
#   Country name  Log GDP per capita
# 1      Denmark               1.908
# 2      Iceland               1.881
# 0      Finland               1.844

# %% [markdown]
# # Adding New Columns:
# # 1. Create a new column called Happiness Category that categorizes countries into three categories based on their Score:
#
# # Low − (Score < 4)
# # Medium − (4 ≤ Score ≤ 6)
# # High − (Score > 6)

# %%
def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
       return 'High'
#['Happiness Category'] adding new column
#
Manifile1['Happiness Category'] = Manifile1['score'].apply(categorize_happiness)

Manifile2=Manifile1[['Country name', 'score', 'Happiness Category']]
Manifile2.to_csv('updated_file.csv')
#helps to create a new file if not found else override it

# %% [markdown]
# # 2. Data Visualizations:

# %% [markdown]
# # • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
import matplotlib.pyplot as plt

#Sort by Score in descending order and select top 10 happiest countries
top_10_happiest = Manifile1.sort_values(by='score', ascending=False).head(10)

#Used for scaling of x and y (width and height) of the individual graph
plt.figure(figsize=(10, 6))
plt.bar(top_10_happiest['Country name'], top_10_happiest['score'], color='skyblue')

#Add labels and title to the bar plot
plt.title('Top 10 Happiest Countries by Score')
plt.ylabel('Score')
plt.xlabel('Country Name')
#rotating the x axis values
plt.xticks(rotation=90)
#Show the plot
plt.show()

# %% [markdown]
# # • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
import matplotlib.pyplot as plt

# assending order is true in default
top_10_unhappiest = Manifile2.sort_values(by='score').head(10)

# Create the line plot using Matplotlib
plt.figure(figsize=(10, 6))
plt.plot(top_10_unhappiest['Country name'], top_10_unhappiest['score'], marker='o', color='black', linestyle='-')

# Add labels and title
plt.title('Top 10 Unhappiest Countries by Score')
plt.xlabel('Country Name')
plt.ylabel('Score')

#rotating the x axis values
plt.xticks(rotation=90)

#background of the fig
plt.grid(visible=True, linestyle='--')

# Show the plot

plt.show()

# %% [markdown]
# # • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
import seaborn as sns# Create the histogram for the Score column
plt.figure(figsize=(10,6))
sns.histplot(Manifile1['score'], bins=20, kde=True, color='skyblue')

# Add labels and title
plt.title('Distribution of Happiness Scores')
plt.xlabel('score')
plt.ylabel('Frequency')
plt.grid(visible=True, linestyle='--')
# Show the plot
plt.show()

# %%
correlation_matrix = Manifile1.drop(columns=['Country name', 'Happiness Category']).corr()
sns.heatmap(correlation_matrix.corr(), annot=True)
plt.title("Correlation Heatmap (Excluding Country Name and Happiness Category)")
plt.show()

# %%
correlation_matrix = Manifile1.drop(columns=['Country name', 'Happiness Category']).corr()
sns.heatmap(correlation_matrix.corr(), annot=True)
plt.title("Correlation Heatmap (Excluding Country Name and Happiness Category)")
plt.show()

# %% [markdown]
# # • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
# Create the scatter plot for GDP per Capita vs Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=Manifile1, color='green')

# Add labels and title
plt.title('Relationship Between GDP per Capita and Happiness Score')
plt.xlabel('Log GDP per capita')
plt.ylabel('score')

# Show the plot
plt.show()

# %% [markdown]
# # 3.2 Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# # Task - 1 - Setup Task - Preparing the South-Asia Dataset:

# %% [markdown]
# # Steps:
# 1. Define the countries in South Asia with a list for example: south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                         "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

filtered_df = Manifile1[Manifile1['Country name'].isin(south_asian_countries)]
print(filtered_df)
filtered_df.to_csv('Manifile3.csv', index=False)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# # Task - 2 - Composite Score Ranking:

# %% [markdown]
# # Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the following metrics:Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support+ 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your discussion with some visualization plot.

# %%
Manifile3 = pd.read_csv('/content/Manifile3.csv')
Manifile3['Composite score']=0.40*Manifile3['Log GDP per capita']+0.30*Manifile3['Social support']+0.30*Manifile3['Healthy life expectancy']
sorted_ab_composite_score = Manifile3.sort_values(by='Composite score', ascending=False)
filtered_ab_five=(sorted_ab_composite_score.head(5))
plt.barh(filtered_ab_five['Country name'],filtered_ab_five['Composite score'])
plt.title('Top 5 countries based on Composite Score')
# Out:
# Text(0.5, 1.0, 'Top 5 countries based on Composite Score')

# %% [markdown]
# # Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
# By using the formula we have figured out Q1 and Q3 of the score and gdp per capita using the score column
Q1_score = Manifile3['score'].quantile(0.25)
Q3_score = Manifile3['score'].quantile(0.75)
#We got IQR (inter Quartile range) by figuring out the difference between the Q3 and Q1
IQR_score = Q3_score - Q1_score
Q1_Gdp = Manifile3['Log GDP per capita'].quantile(0.25)
Q3_Gdp = Manifile3['Log GDP per capita'].quantile(0.75)
IQR_Gdp = Q3_Gdp - Q1_Gdp
#By using given formula we have figured out the lower and upper bound score of both score and Gdp per capita
lower_bound_score = Q1_score -1.5*IQR_score
upper_bound_score = Q3_score +1.5*IQR_score
lower_bound_Gdp = Q1_Gdp -1.5*IQR_Gdp
upper_bound_Gdp = Q3_Gdp +1.5*IQR_Gdp
# | is or operator in python
outliers_score = Manifile3[(Manifile3['score'] < lower_bound_score) | (Manifile3['score'] > upper_bound_score)]
outliers_Gdp = Manifile3[(Manifile3['Log GDP per capita'] < lower_bound_Gdp) | (Manifile3['Log GDP per capita'] > upper_bound_Gdp)]
# By using scatter plot we have plotted the normal in blue color and the outlier in red color

plt.scatter(Manifile3['Log GDP per capita'], Manifile3['score'], color='blue', label='Normal', alpha=1)
plt.scatter(outliers_Gdp['Log GDP per capita'], outliers_score['score'], color='red', label='Outliers', alpha=1)

plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter Plot of Log GDP per Capita vs Score with Outliers')
plt.legend()
plt.show()

# %% [markdown]
# #Task - 4 - Exploring Trends Across Metrics:
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation{pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for South Asian countries.

# %%
freedom_correlation=Manifile3['Freedom to make life choices'].corr(Manifile3['score'])
print(freedom_correlation)
generosity_correlation=Manifile3['Generosity'].corr(Manifile3['score'])
print(generosity_correlation)
plt.figure(figsize=(10, 6))
sns.regplot(x=Manifile3['Freedom to make life choices'],y=Manifile3['score'], scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Regression  Plot of Freedom to make life choices vs score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.show()
plt.figure(figsize=(10, 6))
sns.regplot(x=Manifile3['Generosity'],y=Manifile3['score'], scatter_kws={'color': 'red'}, line_kws={'color': 'yellow'})
plt.title('Regression  Plot of Generosity vs score')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.show()
if freedom_correlation > generosity_correlation:
    print("Freedom to make life choices has a stronger correlation with happiness score.")
else:
    print("Generosity has a stronger correlation with happiness score.")
# Out:
# 0.8005185224163315
# 0.874512371253192
# Generosity has a stronger correlation with happiness score.

# %% [markdown]
# #Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
Manifile3['GDP-Score Gap'] = Manifile3['Log GDP per capita']-Manifile3['score']
ascending = Manifile3.sort_values(by='GDP-Score Gap', ascending=True)
descending = Manifile3.sort_values(by='GDP-Score Gap', ascending=False)
print(ascending[['Country name','GDP-Score Gap']])
print(descending[['Country name','GDP-Score Gap']])
Manifile3['Score_GDP']=Manifile3['score']-Manifile3['Log GDP per capita']
ascending2 = Manifile3.sort_values(by='Score_GDP', ascending=True)
plt.bar(Manifile3.tail(3)['Country name'],Manifile3.tail(3)['Score_GDP'],label="positive gap",color="red")
plt.bar(Manifile3.tail(3)['Country name'],Manifile3.tail(3)['GDP-Score Gap'],label="negative gap",color ="green")
plt.title('Country name vs Gaps')
plt.xlabel('Country name')
plt.ylabel('Gap')
plt.legend()
plt.show()
# Out:
#   Country name  GDP-Score Gap
# 0        Nepal         -4.193
# 1     Pakistan         -3.588
# 2        India         -2.888
# 4   Bangladesh         -2.764
# 3    Sri Lanka         -2.537
# 5  Afghanistan         -1.093
#   Country name  GDP-Score Gap
# 5  Afghanistan         -1.093
# 3    Sri Lanka         -2.537
# 4   Bangladesh         -2.764
# 2        India         -2.888
# 1     Pakistan         -3.588
# 0        Nepal         -4.193

# %% [markdown]
# #Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]

# %%
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan","Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]
#here like wise in south asian countries we have filterd the countries that lies on middle east region
Manifile4 = Manifile1[Manifile1['Country name'].isin(middle_east_countries)]
# checking for countries name
print(Manifile4)
Manifile4.to_csv('Manifile4.csv', index=False)
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# # 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
Manifile4 = pd.read_csv('/content/Manifile4.csv')
mean = Manifile3['score'].mean()
std = Manifile3['score'].std()
mean2 = Manifile4['score'].mean()
std2 = Manifile4['score'].std()
Manifile4['dif']=mean-mean2
print(Manifile4['dif'])
# Out:
# 0   -1.516433
# 1   -1.516433
# 2   -1.516433
# 3   -1.516433
# 4   -1.516433
# 5   -1.516433
# 6   -1.516433
# 7   -1.516433
# 8   -1.516433
# 9   -1.516433
# Name: dif, dtype: float64

# %% [markdown]
# #2. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
plt.bar(Manifile3.head(3)['Country name'],Manifile3.head(3)['score'],color="red",label="South asian")
plt.bar(Manifile4.head(3)['Country name'],Manifile4.head(3)['score'],color="green",label="Middle east")
plt.xlabel('Country name')
plt.ylabel('score')
plt.title('top 3 countires from South Asia and Middle East')
plt.legend()
plt.show()
plt.bar(Manifile3.tail(3)['Country name'],Manifile3.tail(3)['score'],color="red",label="South asian")
plt.bar(Manifile4.tail(3)['Country name'],Manifile4.tail(3)['score'],color="green",label="Middle east")
plt.xlabel('Country name')
plt.ylabel('score')
plt.title('bottom 3 countires from South Asia and Middle East')
plt.legend()
plt.show()

# %%
import numpy as np
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
s = Manifile3[metrics].mean()
m = Manifile4[metrics].mean()
#here using .mean we have figured out the mean of the metrices
print(s)
print(m)
comparison_df = pd.DataFrame({
    'Metric': metrics,
    'South Asia': s.values,
    'Middle East': m.values
})
x = np.arange(len(metrics))
#it determines the number of grouped bargraph
width = 0.35
# this determines the size of the individual graph
plt.figure(figsize=(10, 6))
plt.bar(x - width/2, s, width, label='South Asia', color='blue')
plt.bar(x + width/2, m, width, label='Middle East', color='red')
plt.xticks(x, metrics, rotation=20)
plt.ylabel('Average Value')
plt.title('Comparison of Key Metrics Between South Asia and Middle East')
plt.legend()
plt.xticks(rotation=90)
plt.show()
gdp=s['Log GDP per capita']-m['Log GDP per capita']
social=s['Social support']-m['Social support']
life=s['Healthy life expectancy']-m['Healthy life expectancy']
if gdp>social and gdp>life:
    print("GDP per capita has the largest disparity between the two regions")
elif social>gdp and social>life:
    print("Social support has the largest disparity between the two regions")
else:
    print("Healthy life expectancy has the largest disparity between the two regions")
# Out:
# Log GDP per capita         1.051833
# Social support             0.611833
# Healthy life expectancy    0.420333
# dtype: float64
# Log GDP per capita         1.496333
# Social support             1.152778
# Healthy life expectancy    0.554111
# dtype: float64
# Healthy life expectancy has the largest disparity between the two regions

# %%
import numpy as np
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
s = Manifile3[metrics].mean()
m = Manifile4[metrics].mean()
#here using .mean we have figured out the mean of the metrices
print(s)
print(m)
comparison_df = pd.DataFrame({
    'Metric': metrics,
    'South Asia': s.values,
    'Middle East': m.values
})
x = np.arange(len(metrics))
#it determines the number of grouped bargraph
width = 0.35
# this determines the size of the individual graph
plt.figure(figsize=(10, 6))
plt.bar(x - width/2, s, width, label='South Asia', color='blue')
plt.bar(x + width/2, m, width, label='Middle East', color='red')
plt.xticks(x, metrics, rotation=20)
plt.ylabel('Average Value')
plt.title('Comparison of Key Metrics Between South Asia and Middle East')
plt.legend()
plt.xticks(rotation=90)
plt.show()
gdp=s['Log GDP per capita']-m['Log GDP per capita']
social=s['Social support']-m['Social support']
life=s['Healthy life expectancy']-m['Healthy life expectancy']
if gdp>social and gdp>life:
    print("GDP per capita has the largest disparity between the two regions")
elif social>gdp and social>life:
    print("Social support has the largest disparity between the two regions")
else:
    print("Healthy life expectancy has the largest disparity between the two regions")
# Out:
# Log GDP per capita         1.051833
# Social support             0.611833
# Healthy life expectancy    0.420333
# dtype: float64
# Log GDP per capita         1.496333
# Social support             1.152778
# Healthy life expectancy    0.554111
# dtype: float64
# Healthy life expectancy has the largest disparity between the two regions

# %% [markdown]
# 4. Happiness Disparity:

# %%
s_range = Manifile3['score'].max() - Manifile3['score'].min()
s_cv = Manifile3['score'].std() / Manifile3['score'].mean()
m_range = Manifile4['score'].max() - Manifile4['score'].min()
m_cv = Manifile4['score'].std() / Manifile4['score'].mean()
print("Happiness Disparity:")
print("South Asia - Range: " , s_range , " CV: ", s_cv)
print("Middle east Asia - Range: " , m_range , " CV: " , m_cv)
if s_cv > m_cv:
    print("South Asia has greater variability in happiness.")
else:
    print("Middle East has greater variability in happiness.")
# Out:
# Happiness Disparity:
# South Asia - Range:  3.4370000000000003  CV:  0.3021482883337427
# Middle east Asia - Range:  4.634  CV:  0.28938880812119405
# South Asia has greater variability in happiness.

# %%
plt.figure(figsize=(10, 6))  # Create a new figure for each metric
plt.scatter(Manifile3['score'],Manifile3['Freedom to make life choices'],color="blue",label="South Asia")
plt.scatter(Manifile4['score'],Manifile4['Freedom to make life choices'],color="red",label="Middle East")
plt.title("Scatter plot of Each region with respect to Freedom to make life choices and scores")
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.legend()
plt.show()
plt.scatter(Manifile3['score'],Manifile3['Generosity'],color="blue",label="South Asia")
plt.scatter(Manifile4['score'],Manifile4['Generosity'],color="red",label="Middle East")
plt.title("Scatter plot of Each region with respect to Generosity and scores")
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.legend()
plt.show()

# %%
Q1_score = Manifile3['score'].quantile(0.25)
Q3_score = Manifile3['score'].quantile(0.75)
Q1_score2 = Manifile4['score'].quantile(0.25)
Q3_score2 = Manifile4['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score
Q1_Gdp = Manifile3['Log GDP per capita'].quantile(0.25)
Q3_Gdp = Manifile3['Log GDP per capita'].quantile(0.75)
IQR_Gdp = Q3_Gdp - Q1_Gdp
IQR_score2 = Q3_score2 - Q1_score2
Q1_Gdp2 = Manifile4['Log GDP per capita'].quantile(0.25)
Q3_Gdp2 = Manifile4['Log GDP per capita'].quantile(0.75)
IQR_Gdp2 = Q3_Gdp2 - Q1_Gdp2
lower_bound_score = Q1_score -1.5*IQR_score
upper_bound_score = Q3_score +1.5*IQR_score
lower_bound_Gdp = Q1_Gdp -1.5*IQR_Gdp
upper_bound_Gdp = Q3_Gdp +1.5*IQR_Gdp
lower_bound_score2 = Q1_score2 -1.5*IQR_score2
upper_bound_score2 = Q3_score2 +1.5*IQR_score2
lower_bound_Gdp2 = Q1_Gdp2 -1.5*IQR_Gdp2
upper_bound_Gdp2= Q3_Gdp2 +1.5*IQR_Gdp2
outliers_score = Manifile3[(Manifile3['score'] < lower_bound_score) | (Manifile3['score'] > upper_bound_score)]
outliers_Gdp = Manifile3[(Manifile3['Log GDP per capita'] < lower_bound_Gdp) | (Manifile3['Log GDP per capita'] > upper_bound_Gdp)]
outliers_score2 = Manifile4[(Manifile4['score'] < lower_bound_score) | (Manifile4['score'] > upper_bound_score)]
outliers_Gdp2 = Manifile4[(Manifile4['Log GDP per capita'] < lower_bound_Gdp) | (Manifile4['Log GDP per capita'] > upper_bound_Gdp)]

plt.scatter(Manifile3['Log GDP per capita'], Manifile3['score'], color='blue', label='South Asian Normal', alpha=0.5)
plt.scatter(outliers_Gdp['Log GDP per capita'], outliers_score['score'], color='red', label='South Asian Outliers', alpha=1)
plt.scatter(Manifile4['Log GDP per capita'], Manifile4['score'], color='yellow', label='Middle East Normal', alpha=0.5)
plt.scatter(outliers_Gdp2['Log GDP per capita'], outliers_score2['score'], color='green', label='Middle East Outliers', alpha=1)

plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter Plot of Log GDP per Capita vs Score with Outliers Highlighted of both South asian and Middle west ')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=pd.concat([Manifile3.assign(Region='South Asia'),
                                                 Manifile4.assign(Region='Middle East')]))
plt.title('Distribution of Scores: South Asia vs Middle East')
plt.show()
print("Boxplot Interpretation:")
print("1. Observe differences in median scores between the regions.")
print("2. Check for the presence of outliers in each region.")
print("3. Analyze the spread and symmetry of the distributions.")
# Out:
# Boxplot Interpretation:
# 1. Observe differences in median scores between the regions.
# 2. Check for the presence of outliers in each region.
# 3. Analyze the spread and symmetry of the distributions.
